# %%
# importando as bibliotecas
import numpy as np
import pandas as pd

# %% [markdown]
# #### Carregando o Conjunto de dados em um quadro de dados usando Pandas

# %%
df = pd.read_csv(r'C:\Users\767912\OneDrive - BRF S.A\Desktop\Andre\Base_Projetos\agricultural_raw_material.csv')

# %% [markdown]
# #### Explorando o conjunto de dados

# %%
df
# Out:
#       Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0    Apr-90            482.34                          -         236
# 1    May-90            447.26                     -7.27%         234
# 2    Jun-90            440.99                     -1.40%         216
# 3    Jul-90            418.44                     -5.11%         205
# 4    Aug-90            418.44                      0.00%         198
# ..      ...               ...                        ...         ...
# 356  Dec-19               NaN                        NaN         NaN
# 357  Jan-20               NaN                        NaN         NaN
# 358  Feb-20               NaN                        NaN         NaN
# 359  Mar-20               NaN                        NaN         NaN
# 360  Apr-20               NaN                        NaN         NaN
#
#     Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# ...

# %%
df.info
#Checando os valores nulos de cada coluna
df.isnull().sum()
# Out:
# Month                            0
# Coarse wool Price               34
# Coarse wool price % Change      34
# Copra Price                     22
# Copra price % Change            22
# Cotton Price                     0
# Cotton price % Change            0
# Fine wool Price                 34
# Fine wool price % Change        34
# Hard log Price                   0
# Hard log price % Change          0
# Hard sawnwood Price             34
# Hard sawnwood price % Change    34
# Hide Price                      34
# Hide price % change             34
# Plywood Price                    0
# Plywood price % Change           0
# Rubber Price                     0
# Rubber price % Change            0
# Softlog Price                   34
# Softlog price % Change          34
# Soft sawnwood Price             34
# Soft sawnwood price % Change    34
# Wood pulp Price                  1
# Wood pulp price % Change         1
# dtype: int64

# %% [markdown]
# #### Lidar com dados ausentes, incorretos e invalidos

# %%
# Substituindo %, "," e "-"
df = df.replace('%','', regex=True)
df = df.replace(',','', regex=True)
df = df.replace('-','', regex=True)
df = df.replace('', np.nan)
df = df.replace('MAY90', np.nan)

#Excluindo linhas com valores 'NaN'

df = df.dropna()

#Checando para identificar se todos os valores nulos foram resolvidos

df.isnull().sum()

#Convertendo os tipos de dados para float

lst = ["Coarse wool Price", "Coarse wool price % Change", "Copra Price", "Copra price % Change", "Cotton Price", "Cotton price % Change", "Fine wool Price", "Fine wool price % Change", "Hard log Price", "Hard log price % Change", "Hard sawnwood Price", "Hard sawnwood price % Change", "Hide Price", "Hide price % change","Plywood Price", "Plywood price % Change", "Rubber Price", "Rubber price % Change", "Softlog Price", "Softlog price % Change", "Soft sawnwood Price", "Soft sawnwood price % Change", "Wood pulp Price", "Wood pulp price % Change"]
df[lst] = df[lst].astype("float")
df.dtypes
# Out:
# Month                            object
# Coarse wool Price               float64
# Coarse wool price % Change      float64
# Copra Price                     float64
# Copra price % Change            float64
# Cotton Price                    float64
# Cotton price % Change           float64
# Fine wool Price                 float64
# Fine wool price % Change        float64
# Hard log Price                  float64
# Hard log price % Change         float64
# Hard sawnwood Price             float64
# Hard sawnwood price % Change    float64
# Hide Price                      float64
# Hide price % change             float64
# Plywood Price                   float64
# Plywood price % Change          float64
# Rubber Price                    float64
# Rubber price % Change           float64
# Softlog Price                   float64
# Softlog price % Change          float64
# Soft sawnwood Price             float64
# Soft sawnwood price % Change    float64
# ...

# %%
df.head()
# Out:
#    Month  Coarse wool Price  Coarse wool price % Change  Copra Price  \
# 1  May90             447.26                        7.27        234.0
# 2  Jun90             440.99                        1.40        216.0
# 3  Jul90             418.44                        5.11        205.0
# 4  Aug90             418.44                        0.00        198.0
# 5  Sep90             412.18                        1.50        196.0
#
#    Copra price % Change  Cotton Price  Cotton price % Change  Fine wool Price  \
# 1                  0.85          1.89                   3.28          1057.18
# 2                  7.69          1.99                   5.29           898.24
# 3                  5.09          2.01                   1.01           895.83
# 4                  3.41          1.79                  10.95           951.22
# 5                  1.01          1.79                   0.00           936.77
#
#    Fine wool price % Change  Hard log Price  ...  Plywood Price  \
# ...

# %% [markdown]
# #### Colunas de data e hora

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 326 entries, 1 to 326
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Month                         326 non-null    object
#  1   Coarse wool Price             326 non-null    float64
#  2   Coarse wool price % Change    326 non-null    float64
#  3   Copra Price                   326 non-null    float64
#  4   Copra price % Change          326 non-null    float64
#  5   Cotton Price                  326 non-null    float64
#  6   Cotton price % Change         326 non-null    float64
#  7   Fine wool Price               326 non-null    float64
#  8   Fine wool price % Change      326 non-null    float64
#  9   Hard log Price                326 non-null    float64
#  10  Hard log price % Change       326 non-null    float64
#  11  Hard sawnwood Price           326 non-null    float64
# ...

# %%
#Formatando a coluna datetime e definindo-a como índice para o conjunto de dados

df.Month = pd.to_datetime(df.Month.str.upper(), format='%b%y', yearfirst=False)

#Indexando o Mês

df = df.set_index('Month')

# %%
df.head()
# Out:
#             Coarse wool Price  Coarse wool price % Change  Copra Price  \
# Month
# 1990-05-01             447.26                        7.27        234.0
# 1990-06-01             440.99                        1.40        216.0
# 1990-07-01             418.44                        5.11        205.0
# 1990-08-01             418.44                        0.00        198.0
# 1990-09-01             412.18                        1.50        196.0
#
#             Copra price % Change  Cotton Price  Cotton price % Change  \
# Month
# 1990-05-01                  0.85          1.89                   3.28
# 1990-06-01                  7.69          1.99                   5.29
# 1990-07-01                  5.09          2.01                   1.01
# 1990-08-01                  3.41          1.79                  10.95
# 1990-09-01                  1.01          1.79                   0.00
#
#             Fine wool Price  Fine wool price % Change  Hard log Price  \
# Month
# ...

# %% [markdown]
# #### Análise exploratória e visualização com matplotlib.pyplot e seaborn

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9,5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
#raw-material list

raw_data=['Coarse wool Price','Copra Price','Cotton Price','Fine wool Price','Hard log Price','Hard sawnwood Price',
         'Hide Price','Plywood Price','Rubber Price','Softlog Price','Soft sawnwood Price','Wood pulp Price']

#fazendo a matriz de correlação
corrmat = df[raw_data].corr()

#definido o tamanho da plotagem
fig = plt.figure(figsize = (12,9))

#masking the upper traingle part size matrix is synmetric(repetitive)
mask = np.triu(np.ones_like(corrmat, dtype=bool))
sns.heatmap(corrmat, vmax = .8,mask=mask, square = True, annot = True)
plt.show()

# %% [markdown]
# ### O mapa de calor mostra a correlação entre as matérias-primas, quanto maior o valor correlacionado, maior a chance de serem duas matérias primas relacionadas, mas não necessariamente.

# %%
plt.figure(figsize=(30,15))
changelist=["Coarse wool price % Change","Copra price % Change", "Cotton price % Change", "Fine wool price % Change",  "Hard log price % Change",  "Hard sawnwood price % Change",  "Hide price % change", "Plywood price % Change", "Rubber price % Change", "Softlog price % Change", "Soft sawnwood price % Change", "Wood pulp price % Change"]
# Gerando a matriz de correlação para o dataset inteiro
corrMatrix = df[changelist].corr()
sns.heatmap(corrMatrix, annot = True)
plt.show()

# %% [markdown]
# #### A partir desse gráfico podemos dizer que quase não há correlação entre a variação percentual dos preços das matérias-primas
#     -o valor negativo implica que duas variáveis estão negativamente correlacionadas (um aumento, outro decréscimo)
#     -Zero implica nenhuma relação
#     -caso contrário, quanto maior o valor, maior a chance de relação.

# %% [markdown]
# ## Lã Grossa

# %%
#Variação da lã grossa ao longo do tempo (Preço e %)
axes = df[["Coarse wool Price", "Coarse wool price % Change"]].plot(figsize=(11, 9), subplots=True, linewidth=1)

# %% [markdown]
# ### Da mesma forma, podemos encontrar a visualização de todos os outros recursos fornecidos no conjunto de dados.

# %% [markdown]
# # Respondendo algumas perguntas

# %% [markdown]
# #### Variação normal do preço de cada matéria-prima

# %%
changelist=["Coarse wool price % Change","Copra price % Change", "Cotton price % Change", "Fine wool price % Change",  "Hard log price % Change",  "Hard sawnwood price % Change",  "Hide price % change", "Plywood price % Change", "Rubber price % Change", "Softlog price % Change", "Soft sawnwood price % Change", "Wood pulp price % Change"]
for i in range (len(changelist)):
    plt.figure(figsize=(12,12))
    df[changelist[i]].hist(figsize=(11, 9), linewidth=1)
    plt.xlabel('% Change')
    plt.ylabel('count')
    plt.legend(changelist[i:],loc='upper center' ,bbox_to_anchor=(1.2,1))

# %% [markdown]
# #### Matéria-prima com o menor preço ao longo dos anos

# %%
plt.figure(figsize=(10,10))
materialslist = ['Coarse wool Price','Copra Price','Cotton Price','Fine wool Price','Hard log Price','Hard sawnwood Price',
         'Hide Price','Plywood Price','Rubber Price','Softlog Price','Soft sawnwood Price','Wood pulp Price']
for i in range(len(materialslist)):
    plt.subplot(4,3,i+1)
    plt.subplots_adjust( hspace=1, wspace=0.5)
    plt.title(materialslist[i])
    plt.plot(df[materialslist[i]])
    plt.xticks(rotation=90)
plt.suptitle("Raw-Materials price comparission")
# Out:
# Text(0.5, 0.98, 'Raw-Materials price comparission')

# %% [markdown]
# #### Podemos ver que o algodão e a borracha, são os preços mais baixos, vamos comparar os dois para entender melhor qual é o mais baixo.

# %%
plt.figure(figsize=(10, 10))
plt.plot(df[['Cotton Price','Rubber Price']])
plt.title("Raw-Materials price comparision")
plt.xlabel('Years')
plt.ylabel('Prices')
plt.legend(['Cotton Price','Rubber Price'],loc='upper center', bbox_to_anchor=(1.2,1))

# %% [markdown]
# #### Agora podemos ver que o algodão é a material prima com o menor preço nos ultimos anos

# %% [markdown]
# ### Agora, vamos identificar qual matéria prima tem a maior e a menor variação de % de preço

# %%
import random as random

# %%
plt.figure(figsize=(12,12))

for i in range(len(changelist)):
    
    r= random.random()
    b= random.random()
    g= random.random()
    color = (r, g, b)
    plt.subplot(4,3,i+1)
    plt.subplots_adjust (hspace = 1, wspace = 0.5)
    plt.plot(df[changelist[i]],c=color)
    plt.xticks(rotation=90)
    plt.title(changelist[i])
    plt.xlabel('Year')
    plt.ylabel('% Change')

# %% [markdown]
# #### Podemos ver que a maior % de mudança, em mais de 50% para a madeira serrada macia e a menor % de mudança é para a madeira compensada, em menos de 20%

# %% [markdown]
# ### Agora vamos indentificar as matérias-primas que tiveram uma mudança drástica no preço

# %%
lowlist = ['Cotton Price', 'Hide Price', 'Softlog Price', 'Hard log Price', 'Soft sawnwood Price', 'Rubber Price']

# Definir o tamanho da figura
plt.figure(figsize=(12, 12))

# Rótulos dos eixos
plt.ylabel('Prices')
plt.xlabel('Years')

# Loop para traçar os gráficos de dispersão
for i in range(len(lowlist)):
    sns.scatterplot(y=df[lowlist[i]], x=df.index, label=lowlist[i])

# Legenda fora do loop
plt.legend(loc='upper center', bbox_to_anchor=(1.2, 1))

# Mostrar o gráfico
plt.show()

# %% [markdown]
# #### A Mudança de preço é drástica para o preço de tora dura entre as matérias de baixo custo, e entre as materias de alto cuso, seria a lã fina.

# %% [markdown]
# ## Em seguida vamos identificar a faixa de preço de matérias-prima de baixo preço

# %%
lowlist = ['Cotton Price', 'Hide Price', 'Softlog Price', 'Hard log Price', 'Soft sawnwood Price', 'Rubber Price']
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.subplots_adjust( hspace=0.5)
    sns.boxplot(x=df[lowlist[i]])

# %% [markdown]
# #### Inclui: O Intervalo interquartil esta entre Q3 e Q1 minimo, primeiro quartil (Q1), mediana, terceiro quartil (Q3), máximo e outliers

# %% [markdown]
# # Inferências e Conclusão

# %% [markdown]
# ####    -Descobrimos as matérias-prima de alta e baixa gama de acordo com seus preços
# ####    -alta e baixa % de variação dos materiais
# ####    -Pudemos identificar a variação de preços ao longo dos anos.
# ####    -Correlação entre eles usando um mapa de calor

# %% [markdown]
# # Trabalho Futuro
# #### - Além disso, poderíamos descobrir a relação entre as matérias-prima em detalhes, e com ajuda do conhecimento do negócio, poderíamos descobrir as matérias-prima mais próximas.
# #### -Também poderiamos prever os preços das matérias-prima, analisando os anos anteriores.
# #### -Prevendo a variação de preços e com base nisso, poderíamos planejar nosso uso de matéria-prima com antecedência para o próximo ano e descobrir quaisquer materiais alternativos.
